# %%
from msal import ConfidentialClientApplication
import pandas as pd
import os
from azure.keyvault.secrets import SecretClient
from azure.identity import DefaultAzureCredential
import logging, time

def_credential = DefaultAzureCredential()  

## connect to Azure Key Vault securely
##keyVaultName = os.environ["KEY_VAULT_NAME"]
keyVaultName = "sea-it-prd-func-idgov-kv"
KVUri = f"https://{keyVaultName}.vault.azure.net"
kv_client = SecretClient(vault_url=KVUri, credential=def_credential)

## Secret Keys for Bolddesk
api_key       = kv_client.get_secret('infosec-api-key').value

## Secret Keys for Azure App Registration
tenant_id = kv_client.get_secret('azure-tenant-id').value
client_id = kv_client.get_secret('idgov-app-client-id').value
client_secret = kv_client.get_secret('idgov-app-client-secret').value

# %%
import sys
sys.path.append('../')
# from module.azure_ad import AzureAD
from module.infosec import Infosec 
from module.warehouse import Warehouse
from module.azure_ad import AzureAD

## Initialize AD and Bolddesk API Module
url = 'https://securityiq-eu.infosecinstitute.com/api/v2'
ad = AzureAD(tenant_id, client_id, client_secret)
ifs = Infosec(url, api_key)

## initialize warehouse
wh = Warehouse(
    ##server=os.environ["DB_SERVER"],
    server="nera-sql.database.windows.net",
    ##database=os.environ["DB_NAME"],
    database="nera_db",
    credential=def_credential
)

# %%
ifs.list_timeline_events()
# Out:
#      learner_id email first_name last_name campaign_id run_id status  \
# 0          rHM7  None       None      None         GiT   None   None
# 1          rHM7  None       None      None         GiT   None   None
# 2          rHM7  None       None      None         GiT   None   None
# 3          rHM7  None       None      None         GiT   None   None
# 4          rHM7  None       None      None         GiT   None   None
# ...         ...   ...        ...       ...         ...    ...    ...
# 4084       ALSB  None       None      None         GiT   None   None
# 4085       IOUi  None       None      None         GiT   None   None
# 4086       I55b  None       None      None         GiT   None   None
# 4087       IOUi  None       None      None         GiT   None   None
# 4088       ALSB  None       None      None         GiT   None   None
#
#      completed_on
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 4084         None
# 4085         None
# 4086         None
# 4087         None
# 4088         None
#
# [4089 rows x 8 columns]

# %%
ifs.list_timeline_events()
# Out:
#      learner_id email first_name last_name campaign_id run_id status  \
# 0          rHM7  None       None      None         GiT   None   None
# 1          rHM7  None       None      None         GiT   None   None
# 2          rHM7  None       None      None         GiT   None   None
# 3          rHM7  None       None      None         GiT   None   None
# 4          rHM7  None       None      None         GiT   None   None
# ...         ...   ...        ...       ...         ...    ...    ...
# 4084       ALSB  None       None      None         GiT   None   None
# 4085       IOUi  None       None      None         GiT   None   None
# 4086       I55b  None       None      None         GiT   None   None
# 4087       IOUi  None       None      None         GiT   None   None
# 4088       ALSB  None       None      None         GiT   None   None
#
#      completed_on
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 4084         None
# 4085         None
# 4086         None
# 4087         None
# 4088         None
#
# [4089 rows x 8 columns]

# %%
df = pd.DataFrame()
cam_runs     = ifs.list_awareness_campaigns_runs()
for cr in cam_runs:
    run_ids = [r.get('id') for r in cr.get('runs')]
    campaign_id = cr.get('campaign').get('id')
    print(campaign_id)
    temp_df = ifs.list_campaignRunsLearners(campaign = campaign_id, runs = run_ids)
    df = pd.concat([df, temp_df], axis=0)
# Out:
# GlV
# GSZ
# GSj
# GSy
# GiT
# YIM
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\3211662414.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, temp_df], axis=0)
# csn

# %%
cam_runs
# Out:
# [{'campaign': {'id': 'GlV',
#    'name': 'NERA Cybersecurity Awareness Training 2023',
#    'type': 'awareness',
#    'running': False},
#   'runs': [{'id': 'cWr',
#     'campaign_id': 'GlV',
#     'start': '2023-07-09T16:00:00+00:00',
#     'end': '2023-07-15T16:00:00+00:00',
#     'run_number': 1}]},
#  {'campaign': {'id': 'GSZ',
#    'name': 'NERA Cybersecurity Awareness Training 2023 part 1',
#    'type': 'awareness',
#    'running': False},
#   'runs': [{'id': 'c0i',
#     'campaign_id': 'GSZ',
#     'start': '2023-07-17T16:00:00+00:00',
#     'end': '2023-08-11T16:00:00+00:00',
#     'run_number': 1}]},
#  {'campaign': {'id': 'GSj',
#    'name': 'NERA Cybersecurity Awareness Training 2023 part 2',
#    'type': 'awareness',
#    'running': False},
#   'runs': [{'id': 'c0u',
#     'campaign_id': 'GSj',
#     'start': '2023-07-17T16:00:00+00:00',
#     'end': '2023-08-11T16:00:00+00:00',
#     'run_number': 1}]},
#  {'campaign': {'id': 'GSy',
#    'name': 'NERA Cybersecurity Awareness Training 2023  part 3',
#    'type': 'awareness',
#    'running': False},
#   'runs': [{'id': 'c2K',
#     'campaign_id': 'GSy',
#     'start': '2023-07-17T16:00:00+00:00',
#     'end': '2023-08-11T16:00:00+00:00',
#     'run_number': 1}]},
#  {'campaign': {'id': 'GiT',
#    'name': 'NERA Cybersecurity Awareness Training 2023',
#    'type': 'awareness',
#    'running': True},
#   'runs': []},
#  {'campaign': {'id': 'YIM',
#    'name': 'NERA Group IT Policies',
#    'type': 'awareness',
#    'running': True},
#   'runs': [{'id': '148',
#     'campaign_id': 'YIM',
#     'start': '2023-09-11T16:00:00+00:00',
#     'end': '2024-09-10T16:00:00+00:00',
#     'run_number': 1}]},
#  {'campaign': {'id': 'csn',
#    'name': 'NERA Group HR Policies version2',
#    'type': 'awareness',
#    'running': False},
#   'runs': [{'id': 'M4J',
#     'campaign_id': 'csn',
#     'start': '2023-12-20T16:00:00+00:00',
#     'end': '2023-12-26T06:05:04+00:00',
#     'run_number': 1}]}]

# %%
campaign_id = 'GiT'
# Out:
#     learner_id                      email   first_name  last_name campaign_id  \
# 0         TE6y      kehsoon.yong@nera.net     Keh Soon       Yong         GlV
# 1         Tsfi    jacqueline.tan@nera.net   Jacqueline        Tan         GlV
# 2         Tsfu          alex.loh@nera.net         Alex        Loh         GlV
# 3         TsLn     hoiming.chong@nera.net     Hoi Ming      Chong         GlV
# 4         TsLj         aaron.lim@nera.net        Aaron        Lim         GlV
# ..         ...                        ...          ...        ...         ...
# 419       AXLw   muhammad.haroon@nera.net     Muhammad     Haroon         YIM
# 420       A6lq  christopher.yong@nera.net  Christopher       Yong         YIM
# 421       A6lb   hueyshieng.chua@nera.net  Huey Shieng       Chua         YIM
# 0         TsLe      soonkuan.kua@nera.net          Kua  Soon Kuan         csn
# 1         raaG         ellen.tan@nera.net        Ellen        Tan         csn
#
#     run_id       status        completed_on
# 0      cWr      started                 NaT
# 1      cWr  not_started                 NaT
# 2      cWr  not_started                 NaT
# 3      cWr    completed 2023-08-18 07:23:24
# 4      cWr    completed 2023-07-31 09:31:04
# ..     ...          ...                 ...
# 419    148  not_started                 NaT
# 420    148    completed 2024-03-04 09:02:02
# 421    148      started                 NaT
# 0      M4J      started                 NaT
# 1      M4J    completed 2023-12-26 03:24:47
#
# [1563 rows x 8 columns]

# %%
ifs.list_campaignRunsLearners(campaign = campaign_id, runs = run_ids)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30736\75363042.py in ?()
# ----> 1 ifs.list_campaignRunsLearners(campaign = campaign_id, runs = run_ids)
#
# c:\Users\Yong\azure_functions\func-idgov\notebook\..\module\infosec.py in ?(self, campaign, runs)
#      87             df = pd.concat([df,temp_df], axis=0)
#      88
#      89         df.rename(columns = { 'id': 'learner_id'}, inplace=True)
#      90         learners_df = self.list_learners()
# ---> 91         df = df.merge(learners_df, how='left', left_on='learner_id', right_on='id')
#      92         cols = ['learner_id', 'email', 'first_name', 'last_name', 'campaign_id', 'run_id', 'status', 'completed_on']
#      93         df = df[cols]
#      94         return df
#
# c:\Users\Yong\azure_functions\func-idgov\.venv\lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9844         validate: str | None = None,
#    9845     ) -> DataFrame:
#    9846         from pandas.core.reshape.merge import merge
#    9847
# -> 9848         return merge(
#    9849             self,
#    9850             right,
#    9851             how=how,
#
# c:\Users\Yong\azure_functions\func-idgov\.venv\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     140     copy: bool | None = None,
#     141     indicator: str | bool = False,
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
#     146         right,
#     147         how=how,
#
# c:\Users\Yong\azure_functions\func-idgov\.venv\lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     729         (
#     730             self.left_join_keys,
#     731             self.right_join_keys,
#     732             self.join_names,
# --> 733         ) = self._get_merge_keys()
#     734
#     735         # validate the merge keys dtypes. We may need to coerce
#     736         # to avoid incompatible dtypes
#
# c:\Users\Yong\azure_functions\func-idgov\.venv\lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1205                     if lk is not None:
#    1206                         # Then we're either Hashable or a wrong-length arraylike,
#    1207                         #  the latter of which will raise
#    1208                         lk = cast(Hashable, lk)
# -> 1209                         left_keys.append(left._get_label_or_level_values(lk))
#    1210                         join_names.append(lk)
#    1211                     else:
#    1212                         # work-around for merge_asof(left_index=True)
#
# c:\Users\Yong\azure_functions\func-idgov\.venv\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'learner_id'

# %%
ifs.list_campaignRunsLearners('YIM',[148])
# Out:
#     learner_id                      email   first_name          last_name
# 0         TE6y      kehsoon.yong@nera.net     Keh Soon               Yong  \
# 1         TsUM  erwin.novriyanto@nera.net        Erwin         Novriyanto
# 2         TsUa         minmyatoo@nera.net         Mike        Min Myat Oo
# 3         TsU6           alan.ng@nera.net         Alan                 Ng
# 4         TsU8         alfie.ong@nera.net        Alfie                Ong
# ..         ...                        ...          ...                ...
# 428       rTOT    hammad.paracha@nera.net   Hammad Ali            Paracha
# 429       rTf8       mark.lumame@nera.net         Mark  Jay Lumame Abueme
# 430       rrDD       rahmatullah@nera.net  Rahmatullah         Nurhidayat
# 431       rroW       hweeyee.sng@nera.net     Hwee Yee                Sng
# 432       rALT         alvin.lin@nera.net        Alvin         Lin Junqin
#
#     campaign_id  run_id       status        completed_on
# 0           YIM     148    completed 2023-09-12 09:11:34
# 1           YIM     148    completed 2023-09-13 06:47:32
# 2           YIM     148  not_started                 NaT
# 3           YIM     148  not_started                 NaT
# 4           YIM     148  not_started                 NaT
# ..          ...     ...          ...                 ...
# 428         YIM     148  not_started                 NaT
# 429         YIM     148    completed 2023-09-12 09:28:42
# 430         YIM     148  not_started                 NaT
# 431         YIM     148  not_started                 NaT
# 432         YIM     148  not_started                 NaT
#
# [433 rows x 8 columns]

# %%
cols = ['learner_id', 'email', 'first_name', 'last_name', 'campaign_id', 'run_id', 'status', 'completed_on']
df = pd.DataFrame(columns=cols)
